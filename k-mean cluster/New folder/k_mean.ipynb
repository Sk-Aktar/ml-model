# %%
import pandas as pd
df=pd.read_csv("kmeans_dataset_v2.csv")
df.head()
# Out:
#    Feature1  Feature2  TrueCluster
# 0  4.942514  1.218894            1
# 1  2.504166  4.708716            4
# 2 -8.216121  6.184690            3
# 3  4.848262 -0.068565            1
# 4 -6.299994 -6.554313            2

# %%
x=df[["Feature1","Feature2"]]

# %%
from sklearn.cluster import KMeans
i=[]
for k in range(1,11):
    q = KMeans(n_clusters=k, random_state=42)
    q.fit(x)
    i.append(q.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1,11),i,'bo-')
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal k")
plt.show()

# %%
kmeans = KMeans(n_clusters=4)
df['Cluster'] = kmeans.fit_predict(x)

# %%
plt.scatter(df["Feature1"], df["Feature2"], c=df["Cluster"], cmap="viridis", alpha=0.6)
plt.xlabel("Feature1")
plt.ylabel("Feature2")
plt.title("K-Means Clustering")
plt.colorbar(label="Cluster")
plt.show()

# %%
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(x, df['Cluster'])
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Silhouette Score: 0.7307291279449716
