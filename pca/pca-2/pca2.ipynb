# %%
import pandas as pd
df=pd.read_csv("pca_dataset_v2.csv")
df.head()
# Out:
#    Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  Feature7  \
# 0  0.696469  0.286139  0.226851  0.551315  0.719469  0.423106  0.980764
# 1  0.438572  0.059678  0.398044  0.737995  0.182492  0.175452  0.531551
# 2  0.722443  0.322959  0.361789  0.228263  0.293714  0.630976  0.092105
# 3  0.426351  0.893389  0.944160  0.501837  0.623953  0.115618  0.317285
# 4  0.519485  0.612895  0.120629  0.826341  0.603060  0.545068  0.342764
#
#    Feature8  Feature9  Feature10  Feature11  Feature12
# 0  0.684830  0.480932   0.392118   0.343178   0.729050
# 1  0.531828  0.634401   0.849432   0.724455   0.611024
# 2  0.433701  0.430863   0.493685   0.425830   0.312261
# 3  0.414826  0.866309   0.250455   0.483034   0.985560
# 4  0.304121  0.417022   0.681301   0.875457   0.510422

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df)

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
x_pca=pca.fit_transform(x)

# %%
df_pca = pd.DataFrame(data=x_pca, columns=['PC1', 'PC2'])
df_pca.head()
# Out:
#         PC1       PC2
# 0  0.057908 -0.886982
# 1  0.212367 -1.011871
# 2  0.552745  0.032821
# 3  0.375722 -0.723180
# 4 -1.267767 -0.006626

# %%
import matplotlib.pyplot as plt
plt.scatter(df_pca["PC1"], df_pca["PC2"], alpha=0.5)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Result')
plt.show()
