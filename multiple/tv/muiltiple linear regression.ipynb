# %% [markdown]
# multiple linear regression

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
adv= pd.read_csv('advertising.csv')
adv.shape
# Out:
# (200, 4)

# %%
adv.sample(5)
# Out:
#         TV  Radio  Newspaper  Sales
# 26   142.9   29.3       12.6   15.0
# 105  137.9   46.4       59.0   19.2
# 50   199.8    3.1       34.6   11.4
# 132    8.4   27.2        2.1    5.7
# 127   80.2    0.0        9.2    8.8

# %%
adv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
adv.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %%
adv.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
x=adv[['TV', 'Radio', 'Newspaper']]
y=adv['Sales']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=100)

# %%
y_train
# Out:
# 74     17.0
# 3      18.5
# 185    22.6
# 26     15.0
# 90     11.2
#        ...
# 87     16.0
# 103    14.7
# 67     13.4
# 24      9.7
# 8       4.8
# Name: Sales, Length: 140, dtype: float64

# %%
y_train.shape, x_train.shape, y_test.shape, x_test.shape
# Out:
# ((140,), (140, 3), (60,), (60, 3))

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print("Intercept:", lm.intercept_)
print("Coefficients:", lm.coef_)
# Out:
# Intercept: 2.652789668879498
# Coefficients: [0.0454256  0.18975773 0.00460308]

# %%
x_test.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper'], dtype='object')

# %%
coeff_df = pd.DataFrame(lm.coef_, x_test.columns, columns=['Coefficient'])
coeff_df
# Out:
#            Coefficient
# TV            0.045426
# Radio         0.189758
# Newspaper     0.004603

# %%
y_pred = lm.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 1.8506819941636963
# R-squared: 0.9058622107532246

# %%
x_train_new=x_train[['TV', 'Radio']]
x_test_new=x_test[['TV', 'Radio']]

# %%
lm.fit(x_train_new, y_train)
# Out:
# LinearRegression()

# %%
y_pred_new = lm.predict(x_test_new)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred_new)
r2 = r2_score(y_test, y_pred_new)
print("Mean Squared Error (new model):", mse)
print("R-squared (new model):", r2)
# Out:
# Mean Squared Error (new model): 1.7847400520902805
# R-squared (new model): 0.909216449171822

# %%
sales_pred = lm.predict([[44.5,43.45]])
sales_pred
# Out:
# array([13.1088723])

# %% [markdown]
# simple linear regression

# %%
import numpy as np
import pandas as pd
adv = pd.read_csv('advertising.csv')
x_news=adv['Newspaper']
y_news=adv['Sales']
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_news, y_news, train_size=0.7, random_state=110)
x_train=np.reshape(x_train, (-1, 1))
x_test=np.reshape(x_test, (-1, 1))
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train, y_train)
y_pred = lm.predict(x_test)
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error (Newspaper):", mse)
print("R-squared (Newspaper):", r2)
# Out:
# Mean Squared Error (Newspaper): 23.84732008485191
# R-squared (Newspaper): 0.08182413570736657
