# %%
import pandas as pd
df=pd.read_csv("sport_knn.csv")
df.head()
# Out:
#    Age  WeeklyTrainingHours LikesSport
# 0   53                    7         No
# 1   43                    2        Yes
# 2   29                    2        Yes
# 3   57                    0         No
# 4   22                   10        Yes

# %%
df.count()
# Out:
# Age                    100
# WeeklyTrainingHours    100
# LikesSport_Yes         100
# dtype: int64

# %%
dfe=pd.get_dummies(df,drop_first='No')
df=dfe.astype(int)

# %%
df.head()
# Out:
#    Age  WeeklyTrainingHours  LikesSport_Yes
# 0   53                    7               0
# 1   43                    2               1
# 2   29                    2               1
# 3   57                    0               0
# 4   22                   10               1

# %%
x=df.drop("LikesSport_Yes",axis=1)
y=df['LikesSport_Yes']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 1.15607343,  0.59617972],
#        [-1.60136199,  0.59617972],
#        [ 0.26177005, -0.30940973],
#        [-1.07968502, -1.51686234],
#        [ 1.52869984,  0.89804288],
#        [-0.03633107,  1.19990603],
#        [-1.07968502, -1.51686234],
#        [-1.1542103 ,  1.19990603],
#        [-1.1542103 , -1.51686234],
#        [ 1.52869984,  0.89804288],
#        [ 1.60322512,  0.59617972],
#        [-0.48348276, -0.00754658],
#        [-0.63253333,  0.59617972],
#        [ 0.41082061, -1.51686234],
#        [ 1.52869984, -1.21499918],
#        [ 1.52869984, -0.91313603],
#        [ 0.03819421, -1.51686234],
#        [ 0.4853459 ,  0.59617972],
#        [-0.03633107, -0.30940973],
#        [-1.22873558, -0.91313603],
#        [ 0.11271949, -1.21499918],
#        [ 1.00702287,  1.19990603],
#        [ 0.11271949, -1.51686234],
#        [ 1.15607343, -0.61127288],
#        [ 1.37964928,  0.29431657],
#        [ 0.18724477,  0.59617972],
#        [ 0.41082061, -1.51686234],
#        [-0.48348276, -1.21499918],
#        [-0.11085636,  0.29431657],
#        [-1.60136199,  1.50176918],
#        [ 1.23059871, -1.21499918],
#        [-1.1542103 ,  1.50176918],
#        [ 1.60322512, -0.61127288],
#        [ 0.33629533,  0.29431657],
#        [-0.18538164, -0.30940973],
#        [-0.40895748, -0.61127288],
#        [-0.18538164, -0.91313603],
#        [-1.22873558, -0.00754658],
#        [-1.67588727,  0.29431657],
#        [-0.55800805,  1.19990603],
#        [ 0.78344702, -0.61127288],
#        [ 1.23059871, -1.51686234],
#        [ 0.03819421, -0.00754658],
#        [ 0.18724477, -0.61127288],
#        [-1.30326086,  0.89804288],
#        [-1.07968502,  1.50176918],
#        [-0.93063445,  0.29431657],
#        [-0.3344322 ,  0.29431657],
#        [-0.93063445,  0.89804288],
#        [ 0.55987118, -0.00754658],
#        [ 0.33629533, -0.91313603],
#        [ 1.45417456, -1.51686234],
#        [-1.00515974,  0.89804288],
#        [-1.67588727, -1.51686234],
#        [-0.70705861,  0.29431657],
#        [-1.60136199,  0.29431657],
#        [ 0.11271949,  0.89804288],
#        [ 0.93249759, -0.91313603],
#        [ 0.93249759,  0.59617972],
#        [ 1.15607343,  1.19990603],
#        [ 1.52869984,  0.59617972],
#        [-0.18538164, -0.91313603],
#        [ 1.52869984, -0.91313603],
#        [ 0.03819421,  1.50176918],
#        [-0.63253333,  1.50176918],
#        [-1.1542103 ,  1.50176918],
#        [-1.60136199,  0.29431657],
#        [-0.70705861,  0.89804288],
#        [ 1.23059871,  1.50176918],
#        [ 0.93249759, -0.61127288],
#        [-0.85610917, -0.91313603],
#        [-0.63253333,  1.19990603],
#        [ 1.08154815, -0.00754658],
#        [-0.25990692,  1.50176918],
#        [-0.55800805,  0.29431657],
#        [ 0.41082061, -0.91313603],
#        [-1.45231142, -1.51686234],
#        [ 0.18724477,  1.50176918],
#        [-0.18538164,  0.29431657],
#        [ 1.60322512, -0.61127288]])

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=11)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
y_pred=knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.65
# Confusion Matrix:
#  [[6 2]
#  [5 7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.55      0.75      0.63         8
#            1       0.78      0.58      0.67        12
#
#     accuracy                           0.65        20
#    macro avg       0.66      0.67      0.65        20
# weighted avg       0.68      0.65      0.65        20
