# %%
import pandas as pd
df=pd.read_csv("temperature_vs_icecream_sales.csv")
df.head()
# Out:
#    Temperature_C  Ice_Cream_Sales
# 0      24.363503       534.235780
# 1      38.767858       773.384645
# 2      33.299849       649.340985
# 3      29.966462       655.763954
# 4      18.900466       334.568903

# %%
df.isnull().sum()
# Out:
# Temperature_C      0
# Ice_Cream_Sales    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Ice_Cream_Sales'], df['Temperature_C'])
plt.xlabel('Ice Cream Sales ($)')
plt.ylabel('Temperature (°C)')
plt.title('Ice Cream Sales vs Temperature')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x = df[['Temperature_C']]
y = df['Ice_Cream_Sales']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2}')
# Out:
# Mean Squared Error: 830.042289828211
# R^2 Score: 0.9634794216999931
