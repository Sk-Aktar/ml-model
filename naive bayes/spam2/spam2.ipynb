# %%
import pandas as pd
df=pd.read_csv("naive_bayes_dataset2.csv")
df.head()
# Out:
#    Email_Length  Num_Links  Num_Attachments Contains_Promotion_Words  \
# 0           935          3                2                      Yes
# 1           683          0                0                      Yes
# 2            80         16                1                      Yes
# 3           480         12                0                       No
# 4          1852          5                2                       No
#
#   Sender_Reputation  Spam
# 0           Average     1
# 1              Good     1
# 2           Average     1
# 3              Good     1
# 4           Average     1

# %%
df=pd.get_dummies(df, columns=['Contains_Promotion_Words'], drop_first=True,dtype=int)
df=pd.get_dummies(df, columns=['Sender_Reputation'], drop_first=True,dtype=int)

df
# Out:
#      Email_Length  Num_Links  Num_Attachments  Spam  \
# 0             935          3                2     1
# 1             683          0                0     1
# 2              80         16                1     1
# 3             480         12                0     1
# 4            1852          5                2     1
# ..            ...        ...              ...   ...
# 995           651         15                2     1
# 996            80          1                0     0
# 997          1793          1                0     1
# 998          1198          0                3     0
# 999           417         12                3     1
#
#      Contains_Promotion_Words_Yes  Sender_Reputation_Good  \
# 0                               1                       0
# 1                               1                       1
# 2                               1                       0
# 3                               0                       1
# ...

# %%
x=df.drop("Spam", axis=1)
y=df["Spam"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train_sc= sc.fit_transform(x_train)
x_test_sc = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train_sc, y_train)
y_pred_class = model.predict(x_test_sc)

# %%
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix
print("F1 Score:", f1_score(y_test, y_pred_class))
print("Accuracy Score:", accuracy_score(y_test, y_pred_class))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_class))
# Out:
# F1 Score: 0.9372693726937269
# Accuracy Score: 0.8866666666666667
# Confusion Matrix:
#  [[ 12  17]
#  [ 17 254]]
